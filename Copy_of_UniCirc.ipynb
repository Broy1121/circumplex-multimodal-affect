# %% [markdown]
# <a href="https://colab.research.google.com/github/Broy1121/circumplex-multimodal-affect/blob/main/Copy_of_UniCirc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using git & GitHub on Google Colaboratory :
# Ever tried using git/GitHub on Google Colaboratory? Want to shift some insanely large directory from Google Drive to your GitHub Repository? Want to directly push Machine Learning models trained on Colab GPUs to GitHub?
#
# Fret not, we will demystify this very topic today Using git & GitHub on Google Colaboratory!
#
# The processes/methodologies described in this notebook works on colab for both public and private repositories. Try not to modify/skip any steps unless you are a git/GitHub expert! Replace all `{variables}` with the actual names that they contain.
#
# ## Getting Started Prerequisites - User Information Needed :
#
# There are some `{variables}` that you will need before actually proceeding to change/modify during the process and replace with your own values.
#
# - `{your_username}` - Your GitHub UserName.
# - `{your_email_id}` - The Email Address associated with your GitHub Account.
# - `{your_password}` - The Password that you use to login to your GitHub Account.
# - `{destination_repo_projectname}` - The Remote GitHub Repository that you wish to work with (This could be other remote hosting Repos too, like GitLab/BitBucket).
# - `{destination_repo_username}` - The Owner of the Remote Repository that you wish to work on (could be yourself if you want to work on your own repository).
#
#
# ## Cloning a Repository :
#
# Cloning is the process of downloading a local copy of a remote repository with priviledges of version control pre-initiated into it! You can clone a remote git repository using the `git clone` command :
# ```
# !git clone https://{your_username}:{your_password}@github.com/{destination_repo_username}/{destination_repo_projectname}.git
# ```
#
# Example :
#
# ```
# !git clone https://khanfarhan10:thatsmypassword@github.com/khanfarhan10/LungSegmentationCustomUNET.git
# ```
#
# **Note** : Please note that we are using our git password for cloning. While not necessary for public repositories, it will cause a problem while remote pushing to the repository, so it's best advised to clone with your password and overall credentials.
#
# ## Changing  the Current Working Directory
# Change the directory to `{destination_repo_username}` using line magic command `%cd` for jupyter notebooks. The default Working Directory on Google Colaboratory is `/content/`. Since we cloned the repository without changing the original working directory, it should be present inside the `/content/` directory. Perform thsi command to change the directory to inside your Local copy of the Remote Repository.
# ```
# %cd /content/{destination_repo_username}
# ```
# Example :
#
# ```
# %cd /content/LungSegmentationCustomUNET
# ```
#
# ## Verify your Steps:
#
# It is probably well and good if you verify that you are going right. We probably don't want to mess up with our GitHub Repository. However with practice you can skip these steps.
#
# #### Pull
#
# Perform Sanity Checks to see if everything works perfectly!
# ```
# !git pull
# ```
#
# If no changes were made to the remote git repo after cloning, the following should be the displayed output :
# ```
# Already up to date.
# ```
#
# #### Status
#
# Similarly check the status of the staged/unstaged changes.
#
# ```
# !git status
# ```
#
# It should display this, with the default branch selected :
#
# ```
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# ```
#
# ## Check Older Logs
#
# Check the previous commits you have made on the repo :
# ```
# !git log -n 4
# ```
#
# Outputs Git Commit IDs with Logs :
#
# ```
# commit 18ccf27c8b2d92b560e6eeab2629ba0c6ea422a5 (HEAD -> main, origin/main, origin/HEAD)
# Author: Farhan Hai Khan <njrfarhandasilva10@gmail.com>
# Date:   Mon May 31 00:12:14 2021 +0530
#
#     Create README.md
#
# commit bd6ee6d4347eca0e3676e88824c8e1118cfbff6b
# Author: khanfarhan10 <njrfarhandasilva10@gmail.com>
# Date:   Sun May 30 18:40:16 2021 +0000
#
#     Add Zip COVID
#
# commit 8a3a12863a866c9d388cbc041a26d49aedfa4245
# Author: khanfarhan10 <njrfarhandasilva10@gmail.com>
# Date:   Sun May 30 18:03:46 2021 +0000
#
#     Add COVID Data
#
# commit 6a16dc7584ba0d800eede70a217d534a24614cad
# Author: khanfarhan10 <njrfarhandasilva10@gmail.com>
# Date:   Sun May 30 16:04:20 2021 +0000
#
#     Removed sample_data using colab (testing)
# ```
#
#
# ## Make changes in the local repo
#
# Make changes from the local repo directory.
#
# These might include various additions, deletions, or edits.
#
# ###### Pro Tip : If you want you can copy paste things from drive to a git repo by:
#
# #### Mount Google Drive:
#
# ```
# from google.colab import drive
# drive.mount('/content/gdrive')
# ```
#
# #### Copy contents using shutil :
# ```
# import shutil,os
#
# # For a folder:
# shutil.copytree(src_folder,des_folder)
#
# # For a file:
# shutil.copy(src_file,des_file)
#
# # Create a ZipFile
# shutil.make_archive(archive_name, 'zip', directory_to_zip)
#
# # Remove Folder
# shutil.rmtree(folder_name)
#
# # Remove File
# os.remove(file_name)
# ```
#
#
# ## Set Git Credentials
# Tell git who exactly are you?
# ```
# !git config --global user.name "{your_username}"
# !git config --global user.email "{your_email_id}"
# !git config --global user.password "{your_password}"
# ```
#
# Example :
# ```
# !git config --global user.name "khanfarhan10"
# !git config --global user.email "njrfarhandasilva10@gmail.com"
# !git config --global user.password "thatsmypassword"
# ```
#
# ## Check Remote Repository URL
# This is the final step to ensuire that no errors have crept in. To check if the remote url is set and configured correctly, Run :
# ```
# !git remote -v
# ```
#
# If configured properly it should output the following :
# ```
# origin	https://{your_username}:{your_password}@github.com/{destination_repo_username}/{destination_repo_projectname}.git (fetch)
# origin	https://{your_username}:{your_password}@github.com/{destination_repo_username}/{destination_repo_projectname}.git (push)
# ```
#
# Example :
# ```
# origin	https://khanfarhan10:thatsmypassword@github.com/khanfarhan10/LungSegmentationCustomUNET.git (fetch)
# origin	https://khanfarhan10:thatsmypassword@github.com/khanfarhan10/LungSegmentationCustomUNET.git (push)
# ```
#
#
# ## Add, Commit, Push
#
# Just the Regular Stuff : `add` (all) the files that you wish to change to your staging area. `commit` or create a version of the repository that you wish to update. `push` or upload your recent changes to your remote git repository. You know what to do.
#
# ```
# !git add .
# !git commit -m "{Message}"
# !git push
# ```
# Enjoy the power of git and GitHub with Google Colaboratory! If you wish to ask a question, feel free to contact me on [LinkedIn](https://www.linkedin.com/in/fkpro/).
#
#
# ## TL;DR Complete Process in Short :
#
# ```
# !git clone https://{your_username}:{your_password}@github.com/{destination_repo_username}/{destination_repo_projectname}.git
# %cd /content/{destination_repo_projectname}
#
# !git config --global user.name "{your_username}"
# !git config --global user.email "{your_email_id}"
# !git config --global user.password "{your_password}"
# ```
#
# Make Your Changes and then run :
#
# ```
# !git add .
# !git commit -m "{Message}"
# !git push
# ```

# %% [markdown]
# # Let's Jump Right Into It!

# %%
# !git clone https://github.com/Broy1121/circumplex-multimodal-affect.git
# Out:
# Cloning into 'circumplex-multimodal-affect'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 40 (delta 15), reused 2 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (40/40), 493.91 KiB | 2.67 MiB/s, done.
# Resolving deltas: 100% (15/15), done.

# %%
# %cd /content/circumplex-multimodal-affect
# Out:
# /content/circumplex-multimodal-affect

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git log -n 4

# %% [markdown]
# # Change Repo!

# %%
# !python colab_setup.py
# Out:
# Installing requirements...
# ...
# Setting up Kaggle API...
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# ...
# 100% 12.7G/12.7G [06:08<00:00, 36.9MB/s]
# Extracting files...
# Dataset location: /root/.cache/kagglehub/datasets/biswajitroyiitj/unicirc-processed-cmu-mosei-meld-features/versions/1
# Dataset copied into data/
# Loading processed_mosei.pkl ...
# Dataset loaded successfully!
# ...

# %%
"""
UniCirc Colab Setup Script

This script prepares the environment for running UniCirc in Google Colab.

Steps:
1. Installs dependencies
2. Configures Kaggle API
3. Downloads the processed CMU-MOSEI dataset
4. Loads the dataset for training
"""

import pickle
import kagglehub
import shutil
import os
import pandas as pd


def install_requirements():
    print("Installing requirements...")
    os.system("pip install -r requirements.txt")


def setup_kaggle():
    print("Setting up Kaggle API...")
    os.system("mkdir -p ~/.kaggle")
    os.system("cp kaggle.json ~/.kaggle/")
    os.system("chmod 600 ~/.kaggle/kaggle.json")


def download_dataset():
    print("Downloading dataset via kagglehub...")

    path = kagglehub.dataset_download(
        "biswajitroyiitj/unicirc-processed-cmu-mosei-meld-features"
    )

    print("Dataset location:", path)

    os.makedirs("data", exist_ok=True)

    for item in os.listdir(path):
        src = os.path.join(path, item)
        dst = os.path.join("data", item)

        if os.path.isdir(src):
            shutil.copytree(src, dst, dirs_exist_ok=True)
        else:
            shutil.copy2(src, dst)

    print("Dataset copied into data/")
    print("Contents of data/:")
    for item in os.listdir("data"):
        print(f"  {item}")


def load_mosei():
    print("\n── Loading CMU-MOSEI ──────────────────────")
    path = "data/processed_mosei.pkl"

    if not os.path.exists(path):
        print(f"ERROR: {path} not found")
        return None

    with open(path, "rb") as f:
        mosei = pickle.load(f)

    print(f"MOSEI loaded — {len(mosei)} videos")
    return mosei


def load_meld():
    print("\n── Loading MELD ───────────────────────────")

    # Possible CSV locations
    paths = {
        "train": [
            "data/MELD.Raw/train/train_sent_emo.csv",
            "data/MELD.Raw/MELD.Raw/train/train_sent_emo.csv",
        ],
        "dev": [
            "data/MELD.Raw/dev_sent_emo.csv",
            "data/MELD.Raw/MELD.Raw/dev_sent_emo.csv",
        ],
        "test": [
            "data/MELD.Raw/test_sent_emo.csv",
            "data/MELD.Raw/MELD.Raw/test_sent_emo.csv",
        ],
    }

    meld = {}
    for split, candidates in paths.items():
        loaded = False
        for p in candidates:
            if os.path.exists(p):
                meld[split] = pd.read_csv(p)
                print(f"MELD {split:5s} loaded — {len(meld[split])} utterances | path: {p}")
                loaded = True
                break
        if not loaded:
            print(f"WARNING: MELD {split} CSV not found. Tried: {candidates}")

    if meld:
        # Show what columns and emotions we have
        if "train" in meld:
            print(f"\nColumns : {meld['train'].columns.tolist()}")
            print(f"Emotions:\n{meld['train']['Emotion'].value_counts().to_string()}")

    return meld


if __name__ == "__main__":
    install_requirements()
    setup_kaggle()
    download_dataset()

    mosei = load_mosei()
    meld  = load_meld()

    # Summary
    print("\n══ Dataset Summary ════════════════════════")
    if mosei:
        print(f"MOSEI  : {len(mosei)} videos loaded ")
    else:
        print("MOSEI  : failed to load")

    if meld:
        total = sum(len(v) for v in meld.values())
        print(f"MELD   : {total} utterances across {len(meld)} splits ")
    else:
        print("MELD   : failed to load")
# Out:
# Installing requirements...
# Setting up Kaggle API...
# ...
# Dataset location: /root/.cache/kagglehub/datasets/biswajitroyiitj/unicirc-processed-cmu-mosei-meld-features/versions/1
# Dataset copied into data/
# Contents of data/:
#   MELD.Raw
#   processed_mosei.pkl
#
# ── Loading CMU-MOSEI ──────────────────────
# MOSEI loaded — 1185 videos
#
# ── Loading MELD ───────────────────────────
# MELD train loaded — 9989 utterances | path: data/MELD.Raw/MELD.Raw/train/train_sent_emo.csv
# MELD dev   loaded — 1109 utterances | path: data/MELD.Raw/MELD.Raw/dev_sent_emo.csv
# MELD test  loaded — 2610 utterances | path: data/MELD.Raw/MELD.Raw/test_sent_emo.csv
#
# Columns : ['Sr No.', 'Utterance', 'Speaker', 'Emotion', 'Sentiment', 'Dialogue_ID', 'Utterance_ID', 'Season', 'Episode', 'StartTime', 'EndTime']
# Emotions:
# Emotion
# neutral     4710
# joy         1743
# surprise    1205
# anger       1109
# sadness      683
# disgust      271
# fear         268
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os

# Check video files exist
video_dirs = [
    "data/MELD.Raw/MELD.Raw/train/train_splits",
    "data/MELD.Raw/MELD.Raw/test/output_repeated_",
    "data/MELD.Raw/MELD.Raw/dev/dev_splits_complete",
]

for d in video_dirs:
    if os.path.exists(d):
        files = os.listdir(d)
        mp4s  = [f for f in files if f.endswith('.mp4')]
        print(f"✅ {d}")
        print(f"   Total files : {len(files)}")
        print(f"   MP4 files   : {len(mp4s)}")
        if mp4s:
            print(f"   Sample name : {mp4s[0]}")
    else:
        print(f"❌ Not found: {d}")
# Out:
# ✅ data/MELD.Raw/MELD.Raw/train/train_splits
#    Total files : 9989
#    MP4 files   : 9989
#    Sample name : dia980_utt6.mp4
# ❌ Not found: data/MELD.Raw/MELD.Raw/test/output_repeated_
# ✅ data/MELD.Raw/MELD.Raw/dev/dev_splits_complete
#    Total files : 1112
#    MP4 files   : 1112
#    Sample name : dia104_utt3.mp4

# %%
import pickle

with open("data/processed_mosei.pkl", "rb") as f:
    mosei = pickle.load(f)

sample_key = list(mosei.keys())[0]
sample_val = mosei[sample_key]

print("Top-level type:", type(mosei))
print("Sample key:", sample_key)
print("Value type:", type(sample_val))
print("Value length:", len(sample_val))

# Peek inside the list
for i, item in enumerate(sample_val):
    print(f"  [{i}] type={type(item).__name__}", end="")
    if hasattr(item, 'shape'):
        print(f"  shape={item.shape}", end="")
    elif isinstance(item, dict):
        print(f"  keys={list(item.keys())}", end="")
    elif isinstance(item, (list, tuple)):
        print(f"  len={len(item)}", end="")
    else:
        print(f"  val={item}", end="")
    print()


##What you're likely seeing** is that MOSEI is stored as a list of segments per video ID, where each segment is either a tuple or a sub-list like:
#
# Out:
# Top-level type: <class 'dict'>
# Sample key: -3g5yACwYnA
# Value type: <class 'list'>
# Value length: 6
#   [0] type=dict  keys=['Labels', 'COVAREP', 'FACET', 'WORDVEC']
#   [1] type=dict  keys=['Labels', 'COVAREP', 'FACET', 'WORDVEC']
#   [2] type=dict  keys=['Labels', 'COVAREP', 'FACET', 'WORDVEC']
#   [3] type=dict  keys=['Labels', 'COVAREP', 'FACET', 'WORDVEC']
#   [4] type=dict  keys=['Labels', 'COVAREP', 'FACET', 'WORDVEC']
#   [5] type=dict  keys=['Labels', 'COVAREP', 'FACET', 'WORDVEC']

# %%
import pickle
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torch.optim.lr_scheduler import CosineAnnealingLR
import warnings
warnings.filterwarnings("ignore", message="Mean of empty slice")

# ── Device ─────────────────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")

# ═══════════════════════════════════════════════════════════
# 1. HELPERS
# ═══════════════════════════════════════════════════════════
def extract_va(label_features):
    valence = float(label_features[0])
    arousal = float(np.max(label_features[[1, 3, 4, 6]]))  # happiness, anger, surprise, fear
    return valence, arousal

def clean_features(features):
    features = features.copy()
    features[~np.isfinite(features)] = 0.0
    return features

def pad_sequence_2d(features, max_len):
    T, D = features.shape
    if T >= max_len:
        return features[:max_len]
    pad = np.zeros((max_len - T, D), dtype=np.float32)
    return np.vstack([features, pad])

MAX_TEXT   = 40
MAX_AUDIO  = 600
MAX_VISION = 200

# ═══════════════════════════════════════════════════════════
# 2. DATASET
# ═══════════════════════════════════════════════════════════
class MOSEITemporalDataset(Dataset):
    def __init__(self, mosei_dict):
        self.samples = []
        for video_id, utterances in mosei_dict.items():
            for seg in utterances:
                try:
                    labels_raw  = np.array(seg['Labels']).item()
                    covarep_raw = np.array(seg['COVAREP']).item()
                    facet_raw   = np.array(seg['FACET']).item()
                    wordvec_raw = np.array(seg['WORDVEC']).item()

                    text   = pad_sequence_2d(clean_features(wordvec_raw['features'].astype(np.float32)), MAX_TEXT)
                    audio  = pad_sequence_2d(clean_features(covarep_raw['features'].astype(np.float32)), MAX_AUDIO)
                    vision = pad_sequence_2d(clean_features(facet_raw['features'].astype(np.float32)),   MAX_VISION)

                    valence, arousal = extract_va(labels_raw['features'])
                    if not (np.isfinite(valence) and np.isfinite(arousal)):
                        continue

                    self.samples.append({
                        'text':    torch.tensor(text),
                        'audio':   torch.tensor(audio),
                        'vision':  torch.tensor(vision),
                        'valence': torch.tensor(valence, dtype=torch.float32),
                        'arousal': torch.tensor(arousal, dtype=torch.float32),
                    })
                except Exception as e:
                    print(f"Skipped {video_id}: {e}")

    def __len__(self): return len(self.samples)
    def __getitem__(self, idx): return self.samples[idx]

def collate_fn(batch):
    return {
        'text':    torch.stack([s['text']    for s in batch]),
        'audio':   torch.stack([s['audio']   for s in batch]),
        'vision':  torch.stack([s['vision']  for s in batch]),
        'valence': torch.stack([s['valence'] for s in batch]),
        'arousal': torch.stack([s['arousal'] for s in batch]),
    }

# Build
dataset = MOSEITemporalDataset(mosei)
print(f"Total utterances: {len(dataset)}")

s = dataset[0]
print(f"text={s['text'].shape} audio={s['audio'].shape} vision={s['vision'].shape}")
print(f"valence={s['valence'].item():.4f}  arousal={s['arousal'].item():.4f}")

# Splits
total   = len(dataset)
n_train = int(0.8 * total)
n_val   = int(0.1 * total)
n_test  = total - n_train - n_val

train_set, val_set, test_set = random_split(
    dataset, [n_train, n_val, n_test],
    generator=torch.Generator().manual_seed(42)
)

train_loader = DataLoader(train_set, batch_size=32, shuffle=True,  collate_fn=collate_fn)
val_loader   = DataLoader(val_set,   batch_size=32, shuffle=False, collate_fn=collate_fn)
test_loader  = DataLoader(test_set,  batch_size=32, shuffle=False, collate_fn=collate_fn)

print(f"Train={len(train_set)}  Val={len(val_set)}  Test={len(test_set)}")

# ═══════════════════════════════════════════════════════════
# 3. MODEL
# ═══════════════════════════════════════════════════════════
class TemporalEncoder(nn.Module):
    def __init__(self, input_dim, hidden_dim=128, num_layers=2, dropout=0.3):
        super().__init__()
        self.gru = nn.GRU(
            input_dim, hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            bidirectional=True,
            dropout=dropout if num_layers > 1 else 0.0
        )
        self.attn = nn.Linear(hidden_dim * 2, 1)
        self.proj = nn.Linear(hidden_dim * 2, hidden_dim)
        self.norm = nn.LayerNorm(hidden_dim)

    def forward(self, x):
        out, _  = self.gru(x)                              # (B, T, H*2)
        weights = torch.softmax(self.attn(out), dim=1)     # (B, T, 1)
        pooled  = (out * weights).sum(dim=1)               # (B, H*2)
        return self.norm(self.proj(pooled))                 # (B, H)

class MultimodalTemporalModel(nn.Module):
    def __init__(self, hidden_dim=128, n_heads=4, dropout=0.3):
        super().__init__()
        self.text_enc   = TemporalEncoder(300, hidden_dim, dropout=dropout)
        self.audio_enc  = TemporalEncoder(74,  hidden_dim, dropout=dropout)
        self.vision_enc = TemporalEncoder(35,  hidden_dim, dropout=dropout)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=hidden_dim, nhead=n_heads,
            dim_feedforward=256, dropout=dropout,
            batch_first=True
        )
        self.fusion  = nn.TransformerEncoder(encoder_layer, num_layers=2)
        self.va_head = nn.Sequential(
            nn.Linear(hidden_dim * 3, 64),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(64, 2)
        )

    def forward(self, text, audio, vision):
        t = self.text_enc(text).unsqueeze(1)
        a = self.audio_enc(audio).unsqueeze(1)
        v = self.vision_enc(vision).unsqueeze(1)
        tokens = torch.cat([t, a, v], dim=1)       # (B, 3, H)
        fused  = self.fusion(tokens)
        flat   = fused.reshape(fused.size(0), -1)
        out    = self.va_head(flat)
        return out[:, 0], out[:, 1]

# ═══════════════════════════════════════════════════════════
# 4. TRAINING UTILITIES
# ═══════════════════════════════════════════════════════════
def concordance_correlation_coefficient(pred, target):
    pred_mean, target_mean = pred.mean(), target.mean()
    covariance = ((pred - pred_mean) * (target - target_mean)).mean()
    ccc = (2 * covariance) / (
        pred.var() + target.var() + (pred_mean - target_mean) ** 2 + 1e-8
    )
    return ccc

def va_loss(v_pred, a_pred, v_true, a_true, alpha=0.5):
    mse_v = nn.functional.mse_loss(v_pred, v_true)
    mse_a = nn.functional.mse_loss(a_pred, a_true)
    ccc_v = 1 - concordance_correlation_coefficient(v_pred, v_true)
    ccc_a = 1 - concordance_correlation_coefficient(a_pred, a_true)
    return alpha * (mse_v + mse_a) + (1 - alpha) * (ccc_v + ccc_a)

def run_epoch(loader, train=True):
    model.train() if train else model.eval()
    total_loss, ccc_v_sum, ccc_a_sum = 0, 0, 0
    ctx = torch.enable_grad() if train else torch.no_grad()
    with ctx:
        for batch in loader:
            text   = batch['text'].to(device)
            audio  = batch['audio'].to(device)
            vision = batch['vision'].to(device)
            v_true = batch['valence'].to(device)
            a_true = batch['arousal'].to(device)

            v_pred, a_pred = model(text, audio, vision)
            loss = va_loss(v_pred, a_pred, v_true, a_true)

            if train:
                optimizer.zero_grad()
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
                optimizer.step()

            total_loss += loss.item()
            ccc_v_sum  += concordance_correlation_coefficient(v_pred.detach(), v_true).item()
            ccc_a_sum  += concordance_correlation_coefficient(a_pred.detach(), a_true).item()

    n = len(loader)
    return total_loss / n, ccc_v_sum / n, ccc_a_sum / n

# ═══════════════════════════════════════════════════════════
# 5. SANITY CHECK — forward pass before training
# ═══════════════════════════════════════════════════════════
model     = MultimodalTemporalModel(hidden_dim=128).to(device)
optimizer = optim.AdamW(model.parameters(), lr=3e-4, weight_decay=1e-4)
scheduler = CosineAnnealingLR(optimizer, T_max=30, eta_min=1e-6)

batch = next(iter(train_loader))
with torch.no_grad():
    vp, ap = model(batch['text'].to(device), batch['audio'].to(device), batch['vision'].to(device))

print(f"\nForward pass OK — v_pred:{vp.shape}  a_pred:{ap.shape}")
print(f"Params: {sum(p.numel() for p in model.parameters()):,}")
print(f"NaNs in output: {torch.isnan(vp).any() or torch.isnan(ap).any()}")
# Out:
# Device: cuda
# Total utterances: 10913
# text=torch.Size([40, 300]) audio=torch.Size([600, 74]) vision=torch.Size([200, 35])
# valence=1.0000  arousal=0.6667
# Train=8730  Val=1091  Test=1092
#
# Forward pass OK — v_pred:torch.Size([32])  a_pred:torch.Size([32])
# Params: 1,892,933
# NaNs in output: False

# %% [markdown]
# **flow in diagram:**
# ```
# mosei.pkl
#     ↓
# MOSEITemporalDataset    (clean, pad, extract labels)
#     ↓
# random_split            (80/10/10)
#     ↓
# DataLoader              (batches of 32)
#     ↓
# MultimodalTemporalModel (GRU encoders + Transformer fusion)
#     ↓
# va_loss                 (MSE + CCC)
#     ↓
# AdamW optimizer         (updates weights)
#     ↓
# CosineAnnealingLR       (reduces learning rate over time)
#     ↓
# Training loop × 30      (saves best checkpoint)

# %%
EPOCHS = 30
best_val_loss = float('inf')
history = []

for epoch in range(1, EPOCHS + 1):
    tr_loss, tr_ccc_v, tr_ccc_a = run_epoch(train_loader, train=True)
    vl_loss, vl_ccc_v, vl_ccc_a = run_epoch(val_loader,   train=False)
    scheduler.step()

    history.append({
        'epoch': epoch,
        'tr_loss': tr_loss, 'vl_loss': vl_loss,
        'tr_ccc_v': tr_ccc_v, 'vl_ccc_v': vl_ccc_v,
        'tr_ccc_a': tr_ccc_a, 'vl_ccc_a': vl_ccc_a,
    })

    if vl_loss < best_val_loss:
        best_val_loss = vl_loss
        torch.save(model.state_dict(), "best_temporal_model.pt")
        tag = " ← best"
    else:
        tag = ""

    if epoch % 5 == 0 or epoch == 1:
        print(
            f"Ep {epoch:02d} | "
            f"Loss {tr_loss:.4f}/{vl_loss:.4f} | "
            f"CCC-V {tr_ccc_v:.3f}/{vl_ccc_v:.3f} | "
            f"CCC-A {tr_ccc_a:.3f}/{vl_ccc_a:.3f}{tag}"
        )

print(f"\nBest val loss: {best_val_loss:.4f}")
# Out:
# Ep 01 | Loss 1.3418/1.1636 | CCC-V 0.344/0.488 | CCC-A 0.245/0.336 ← best
# Ep 05 | Loss 0.9330/0.9178 | CCC-V 0.610/0.647 | CCC-A 0.418/0.405 ← best
# Ep 10 | Loss 0.7559/0.9220 | CCC-V 0.690/0.644 | CCC-A 0.531/0.417
# Ep 15 | Loss 0.6130/0.9463 | CCC-V 0.755/0.645 | CCC-A 0.609/0.420
# Ep 20 | Loss 0.4910/0.9672 | CCC-V 0.801/0.636 | CCC-A 0.684/0.399
# Ep 25 | Loss 0.4273/0.9514 | CCC-V 0.825/0.640 | CCC-A 0.726/0.422
# Ep 30 | Loss 0.4044/0.9524 | CCC-V 0.833/0.640 | CCC-A 0.742/0.410
#
# Best val loss: 0.8876

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2724/369822686.py in <cell line: 0>()
#       3
#       4 with open("training_history.json", "w") as f:
# ----> 5     json.dump(history, f)
#       6
#       7 config = {
#
# NameError: name 'json' is not defined

# %%
# ── Load best checkpoint ───────────────────────────────────
model.load_state_dict(torch.load("best_temporal_model.pt"))
model.eval()

all_v_pred, all_a_pred, all_v_true, all_a_true = [], [], [], []

with torch.no_grad():
    for batch in test_loader:
        vp, ap = model(
            batch['text'].to(device),
            batch['audio'].to(device),
            batch['vision'].to(device)
        )
        all_v_pred.append(vp.cpu())
        all_a_pred.append(ap.cpu())
        all_v_true.append(batch['valence'])
        all_a_true.append(batch['arousal'])

v_pred_all = torch.cat(all_v_pred)
a_pred_all = torch.cat(all_a_pred)
v_true_all = torch.cat(all_v_true)
a_true_all = torch.cat(all_a_true)

ccc_v = concordance_correlation_coefficient(v_pred_all, v_true_all).item()
ccc_a = concordance_correlation_coefficient(a_pred_all, a_true_all).item()
mse_v = nn.functional.mse_loss(v_pred_all, v_true_all).item()
mse_a = nn.functional.mse_loss(a_pred_all, a_true_all).item()

print("── Test Set Results (Temporal Model) ────────────")
print(f"CCC-V : {ccc_v:.4f}   (baseline: 0.6041)")
print(f"CCC-A : {ccc_a:.4f}   (baseline: 0.3931)")
print(f"MSE-V : {mse_v:.4f}   (baseline: 0.7661)")
print(f"MSE-A : {mse_a:.4f}   (baseline: 0.3033)")
# Out:
# ── Test Set Results (Temporal Model) ────────────
# CCC-V : 0.6457   (baseline: 0.6041)
# CCC-A : 0.4549   (baseline: 0.3931)
# MSE-V : 0.7249   (baseline: 0.7661)
# MSE-A : 0.2876   (baseline: 0.3033)

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(14, 6))
fig.patch.set_facecolor('#0a0a0f')

v_t = v_true_all.numpy()
a_t = a_true_all.numpy()
v_p = v_pred_all.numpy()
a_p = a_pred_all.numpy()

for ax in axes:
    ax.set_facecolor('#111118')
    ax.tick_params(colors='#64748b')
    ax.xaxis.label.set_color('#94a3b8')
    ax.yaxis.label.set_color('#94a3b8')
    for spine in ax.spines.values():
        spine.set_edgecolor('#1e1e2e')
    ax.axhline(0, color='#1e1e2e', linewidth=0.8)
    ax.axvline(0, color='#1e1e2e', linewidth=0.8)
    ax.text(0.97, 0.97, 'excited/joyful',  transform=ax.transAxes, ha='right', va='top',    color='#10b981', fontsize=8, alpha=0.7)
    ax.text(0.03, 0.97, 'angry/stressed',  transform=ax.transAxes, ha='left',  va='top',    color='#ef4444', fontsize=8, alpha=0.7)
    ax.text(0.97, 0.03, 'content/relaxed', transform=ax.transAxes, ha='right', va='bottom', color='#7c3aed', fontsize=8, alpha=0.7)
    ax.text(0.03, 0.03, 'sad/bored',       transform=ax.transAxes, ha='left',  va='bottom', color='#64748b', fontsize=8, alpha=0.7)

axes[0].scatter(v_t, a_t, c='#7c3aed', alpha=0.35, s=12, linewidths=0)
axes[0].set_title('Ground Truth — VA Circumplex', color='#e2e8f0', fontsize=11, pad=10)
axes[0].set_xlabel('Valence →')
axes[0].set_ylabel('Arousal →')

axes[1].scatter(v_t, a_t, c='#1e2a3a', alpha=0.6,  s=12, linewidths=0, label='True')
axes[1].scatter(v_p, a_p, c='#0ea5e9', alpha=0.35, s=12, linewidths=0, label='Predicted')
axes[1].set_title('Predicted vs True — VA Circumplex', color='#e2e8f0', fontsize=11, pad=10)
axes[1].set_xlabel('Valence →')
axes[1].set_ylabel('Arousal →')
axes[1].legend(facecolor='#1e1e2e', edgecolor='#2e2e3e', labelcolor='#94a3b8')

fig.suptitle(
    f'Temporal Model — CMU-MOSEI Test Set   |   CCC-V: {ccc_v:.3f}   CCC-A: {ccc_a:.3f}',
    color='#e2e8f0', fontsize=11, y=1.01
)
plt.tight_layout()
plt.savefig('va_circumplex_temporal.png', dpi=150, bbox_inches='tight', facecolor='#0a0a0f')
plt.show()

# ── Training curves ────────────────────────────────────────
fig2, axes2 = plt.subplots(1, 2, figsize=(13, 4))
fig2.patch.set_facecolor('#0a0a0f')
epochs = [h['epoch'] for h in history]

for ax in axes2:
    ax.set_facecolor('#111118')
    ax.tick_params(colors='#64748b')
    for spine in ax.spines.values():
        spine.set_edgecolor('#1e1e2e')

axes2[0].plot(epochs, [h['tr_ccc_v'] for h in history], color='#7c3aed', label='Train CCC-V')
axes2[0].plot(epochs, [h['vl_ccc_v'] for h in history], color='#7c3aed', linestyle='--', label='Val CCC-V')
axes2[0].plot(epochs, [h['tr_ccc_a'] for h in history], color='#0ea5e9', label='Train CCC-A')
axes2[0].plot(epochs, [h['vl_ccc_a'] for h in history], color='#0ea5e9', linestyle='--', label='Val CCC-A')
axes2[0].axvline(15, color='#10b981', linewidth=1, linestyle=':', alpha=0.7)
axes2[0].text(15.3, 0.1, 'best ckpt', color='#10b981', fontsize=8)
axes2[0].set_title('CCC over Epochs', color='#e2e8f0')
axes2[0].set_xlabel('Epoch', color='#94a3b8')
axes2[0].legend(facecolor='#1e1e2e', edgecolor='#2e2e3e', labelcolor='#94a3b8', fontsize=8)

axes2[1].plot(epochs, [h['tr_loss'] for h in history], color='#f59e0b', label='Train Loss')
axes2[1].plot(epochs, [h['vl_loss'] for h in history], color='#f59e0b', linestyle='--', label='Val Loss')
axes2[1].axvline(15, color='#10b981', linewidth=1, linestyle=':', alpha=0.7)
axes2[1].set_title('Loss over Epochs', color='#e2e8f0')
axes2[1].set_xlabel('Epoch', color='#94a3b8')
axes2[1].legend(facecolor='#1e1e2e', edgecolor='#2e2e3e', labelcolor='#94a3b8', fontsize=8)

plt.tight_layout()
plt.savefig('training_curves_temporal.png', dpi=150, bbox_inches='tight', facecolor='#0a0a0f')
plt.show()
print("Saved → va_circumplex_temporal.png  training_curves_temporal.png")
# Out:
# Saved → va_circumplex_temporal.png  training_curves_temporal.png

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

fig, ax = plt.subplots(figsize=(10, 10))
fig.patch.set_facecolor('#0a0a0f')
ax.set_facecolor('#0a0a0f')

# ── Axes ──────────────────────────────────────────────────
ax.axhline(0, color='#444', linewidth=1.2, zorder=1)
ax.axvline(0, color='#444', linewidth=1.2, zorder=1)
ax.set_xlim(-3.5, 3.5)
ax.set_ylim(-0.5, 3.5)
ax.set_xlabel('Valence (Negative ← → Positive)', color='#94a3b8', fontsize=12, labelpad=10)
ax.set_ylabel('Arousal (Calm ← → Excited)', color='#94a3b8', fontsize=12, labelpad=10)
ax.tick_params(colors='#64748b')
for spine in ax.spines.values():
    spine.set_edgecolor('#222')

# ── Axis labels like Russell ───────────────────────────────
ax.text( 3.4,  0.08, 'PLEASURE',   color='#64748b', fontsize=9, ha='right', style='italic')
ax.text(-3.4,  0.08, 'DISPLEASURE',color='#64748b', fontsize=9, ha='left',  style='italic')
ax.text( 0.08, 3.4,  'AROUSAL',    color='#64748b', fontsize=9, ha='left',  style='italic')
ax.text( 0.08,-0.4,  'SLEEP',      color='#64748b', fontsize=9, ha='left',  style='italic')

# ── Emotion words: (valence, arousal, label, color) ───────
# Positioned to match Russell's circumplex layout
emotions = [
    # High arousal, positive valence
    ( 2.5,  3.1, 'ASTONISHED',  '#f59e0b'),
    ( 2.0,  3.0, 'EXCITED',     '#10b981'),
    ( 1.2,  2.5, 'AROUSED',     '#f59e0b'),
    ( 2.2,  2.4, 'DELIGHTED',   '#10b981'),
    ( 1.8,  2.0, 'HAPPY',       '#10b981'),
    ( 2.8,  1.8, 'PLEASED',     '#10b981'),
    ( 2.5,  1.5, 'GLAD',        '#10b981'),

    # High arousal, negative valence
    (-1.5,  2.8, 'ALARMED',     '#ef4444'),
    (-2.0,  2.5, 'AFRAID',      '#ef4444'),
    (-1.2,  2.2, 'TENSE',       '#ef4444'),
    (-2.2,  2.0, 'ANGRY',       '#ef4444'),
    (-2.8,  1.8, 'FRUSTRATED',  '#ef4444'),
    (-1.8,  1.5, 'ANNOYED',     '#f97316'),
    (-2.5,  1.2, 'DISTRESSED',  '#ef4444'),

    # Low arousal, negative valence
    (-3.0,  0.8, 'MISERABLE',   '#8b5cf6'),
    (-2.5,  0.6, 'SAD',         '#8b5cf6'),
    (-2.8,  0.4, 'GLOOMY',      '#8b5cf6'),
    (-2.2,  0.3, 'DEPRESSED',   '#8b5cf6'),
    (-3.0,  0.1, 'BORED',       '#64748b'),
    (-2.0, -0.2, 'DROOPY',      '#64748b'),

    # Low arousal, positive valence
    ( 2.8,  0.8, 'CONTENT',     '#0ea5e9'),
    ( 2.5,  0.6, 'SATISFIED',   '#0ea5e9'),
    ( 2.2,  0.5, 'AT EASE',     '#0ea5e9'),
    ( 3.0,  0.3, 'SERENE',      '#0ea5e9'),
    ( 2.0,  0.2, 'CALM',        '#0ea5e9'),
    ( 2.8,  0.1, 'RELAXED',     '#0ea5e9'),

    # Mid bottom
    ( 0.5, -0.3, 'SLEEPY',      '#475569'),
    ( 1.5, -0.2, 'TIRED',       '#475569'),
]

for vx, ay, label, color in emotions:
    ax.plot(vx, ay, 'o', color=color, markersize=5, zorder=3)
    ax.text(vx + 0.08, ay + 0.05, label, color=color,
            fontsize=8.5, fontweight='bold', zorder=4,
            fontfamily='monospace')

# ── Overlay your model's predictions as density ───────────
v_p = v_pred_all.numpy()
a_p = a_pred_all.numpy()
v_t = v_true_all.numpy()
a_t = a_true_all.numpy()

ax.scatter(v_t, a_t, c='#ffffff', alpha=0.06, s=18, linewidths=0, zorder=2, label='True')
ax.scatter(v_p, a_p, c='#7c3aed', alpha=0.10, s=18, linewidths=0, zorder=2, label='Predicted')

# ── Dashed circle outline like Russell ────────────────────
theta = np.linspace(0, 2 * np.pi, 300)
r = 3.2
ax.plot(r * np.cos(theta), r * np.sin(theta) * 0.55 + 1.5,
        '--', color='#2e2e4e', linewidth=1.0, zorder=1)

# ── Legend + title ────────────────────────────────────────
handles = [
    mpatches.Patch(color='#ffffff', alpha=0.4, label='True VA (test set)'),
    mpatches.Patch(color='#7c3aed', alpha=0.6, label='Predicted VA (test set)'),
]
ax.legend(handles=handles, facecolor='#1e1e2e', edgecolor='#2e2e3e',
          labelcolor='#94a3b8', fontsize=9, loc='lower right')

ax.set_title(
    f'UniCirc — Valence–Arousal Circumplex   |   CCC-V: {ccc_v:.3f}   CCC-A: {ccc_a:.3f}\n'
    f'CMU-MOSEI Test Set · Russell\'s Circumplex Model of Affect',
    color='#e2e8f0', fontsize=11, pad=16
)

plt.tight_layout()
plt.savefig('va_circumplex_russell.png', dpi=150, bbox_inches='tight', facecolor='#0a0a0f')
plt.show()
print("Saved → va_circumplex_russell.png")
# Out:
# Saved → va_circumplex_russell.png

# %% [markdown]
# ### Commit your Changes! Voila!

# %%
seg = mosei[sample_key][0]

for k, v in seg.items():
    import numpy as np
    raw = np.array(v).item() if isinstance(v, np.ndarray) else v
    print(f"\n── {k} ──")
    print(f"  type: {type(raw)}")
    if isinstance(raw, dict):
        for kk, vv in raw.items():
            vv = np.array(vv)
            print(f"    '{kk}': shape={vv.shape}  dtype={vv.dtype}  sample={vv.flat[:3]}")
    elif isinstance(raw, (list, np.ndarray)):
        raw = np.array(raw)
        print(f"  shape={raw.shape}  dtype={raw.dtype}  sample={raw.flat[:3]}")
    else:
        print(f"  value: {raw}")
# Out:
# ── Labels ──
#   type: <class 'dict'>
#     'intervals': shape=(2,)  dtype=float64  sample=[ 82.753 100.555]
#     'features': shape=(7,)  dtype=float32  sample=[1.        0.6666667 0.6666667]
#
# ── COVAREP ──
#   type: <class 'dict'>
#     'intervals': shape=(1779, 2)  dtype=float64  sample=[82.76 82.77 82.77]
#     'features': shape=(1779, 74)  dtype=float32  sample=[1.945000e+02 0.000000e+00 7.899339e-02]
#
# ── FACET ──
#   type: <class 'dict'>
#     'intervals': shape=(533, 2)  dtype=float64  sample=[82.7667 82.8    82.8   ]
#     'features': shape=(533, 35)  dtype=float32  sample=[-1.21083  -0.461787 -0.511508]
#
# ── WORDVEC ──
#   type: <class 'dict'>
#     'intervals': shape=(53, 2)  dtype=float64  sample=[83.25328798 83.50272109 83.50272109]
#     'features': shape=(53, 300)  dtype=float64  sample=[0.33578 0.30902 0.12098]

# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader

def extract_va(label_features):
    """
    label_features: np.array shape (7,)
    Returns valence (float), arousal (float)
    """
    valence = float(label_features[0])  # sentiment score, range ~[-3, 3]
    # Arousal proxy: max activation among high-energy emotions
    arousal = float(np.max(label_features[[1, 3, 4, 6]]))  # happiness, anger, surprise, fear
    return valence, arousal

def pool_features(features, method='mean'):
    """Collapse (T, D) → (D,) via mean or max pooling."""
    if method == 'mean':
        return features.mean(axis=0)
    elif method == 'max':
        return features.max(axis=0)

class MOSEIDataset(Dataset):
    def __init__(self, mosei_dict, pool='mean'):
        self.samples = []

        for video_id, utterances in mosei_dict.items():
            for seg in utterances:
                try:
                    # Unwrap numpy object scalars
                    labels_raw = np.array(seg['Labels']).item()
                    covarep_raw = np.array(seg['COVAREP']).item()
                    facet_raw  = np.array(seg['FACET']).item()
                    wordvec_raw = np.array(seg['WORDVEC']).item()

                    # Extract features (T, D) and pool → (D,)
                    text   = pool_features(wordvec_raw['features'].astype(np.float32), pool)  # (300,)
                    audio  = pool_features(covarep_raw['features'].astype(np.float32), pool)  # (74,)
                    vision = pool_features(facet_raw['features'].astype(np.float32),   pool)  # (35,)

                    # Extract VA labels
                    label_feats = labels_raw['features']  # (7,)
                    valence, arousal = extract_va(label_feats)

                    self.samples.append({
                        'text':    torch.tensor(text),
                        'audio':   torch.tensor(audio),
                        'vision':  torch.tensor(vision),
                        'valence': torch.tensor(valence, dtype=torch.float32),
                        'arousal': torch.tensor(arousal, dtype=torch.float32),
                        'video_id': video_id,
                    })

                except Exception as e:
                    print(f"Skipped {video_id}: {e}")

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        return self.samples[idx]


# ── Sanity check ──────────────────────────────────────────
dataset = MOSEIDataset(mosei)
print(f"Total utterances: {len(dataset)}")

s = dataset[0]
print(f"text   : {s['text'].shape}")    # → (300,)
print(f"audio  : {s['audio'].shape}")   # → (74,)
print(f"vision : {s['vision'].shape}")  # → (35,)
print(f"valence: {s['valence'].item():.4f}")
print(f"arousal: {s['arousal'].item():.4f}")
# Out:
# /tmp/ipykernel_235/861482672.py:18: RuntimeWarning: Mean of empty slice.
#   return features.mean(axis=0)
# /usr/local/lib/python3.12/dist-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# Total utterances: 10913
# text   : torch.Size([300])
# audio  : torch.Size([74])
# vision : torch.Size([35])
# valence: 1.0000
# arousal: 0.6667

# %%
from torch.utils.data import random_split, DataLoader

# ── Split ─────────────────────────────────────────────────
total = len(dataset)
n_train = int(0.8 * total)   # 8,730
n_val   = int(0.1 * total)   #  1,091
n_test  = total - n_train - n_val  # 1,092

train_set, val_set, test_set = random_split(
    dataset, [n_train, n_val, n_test],
    generator=torch.Generator().manual_seed(42)
)

# ── Collate fn (handles dict samples) ─────────────────────
def collate_fn(batch):
    return {
        'text':    torch.stack([s['text']    for s in batch]),   # (B, 300)
        'audio':   torch.stack([s['audio']   for s in batch]),   # (B, 74)
        'vision':  torch.stack([s['vision']  for s in batch]),   # (B, 35)
        'valence': torch.stack([s['valence'] for s in batch]),   # (B,)
        'arousal': torch.stack([s['arousal'] for s in batch]),   # (B,)
    }

train_loader = DataLoader(train_set, batch_size=64, shuffle=True,  collate_fn=collate_fn)
val_loader   = DataLoader(val_set,   batch_size=64, shuffle=False, collate_fn=collate_fn)
test_loader  = DataLoader(test_set,  batch_size=64, shuffle=False, collate_fn=collate_fn)

# ── Verify ────────────────────────────────────────────────
batch = next(iter(train_loader))
for k, v in batch.items():
    print(f"{k:8s}: {v.shape}")
# Out:
# text    : torch.Size([64, 300])
# audio   : torch.Size([64, 74])
# vision  : torch.Size([64, 35])
# valence : torch.Size([64])
# arousal : torch.Size([64])

# %%
import torch.nn as nn

class ModalEncoder(nn.Module):
    """Projects each modality to a shared hidden dim."""
    def __init__(self, input_dim, hidden_dim=128, dropout=0.3):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, hidden_dim),
        )
    def forward(self, x):
        return self.net(x)   # (B, hidden_dim)


class MultimodalFusionModel(nn.Module):
    def __init__(self, hidden_dim=128, n_heads=4, dropout=0.3):
        super().__init__()

        # Per-modality encoders
        self.text_enc   = ModalEncoder(300, hidden_dim, dropout)
        self.audio_enc  = ModalEncoder(74,  hidden_dim, dropout)
        self.vision_enc = ModalEncoder(35,  hidden_dim, dropout)

        # Transformer fusion over 3 tokens (text, audio, vision)
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=hidden_dim, nhead=n_heads,
            dim_feedforward=256, dropout=dropout,
            batch_first=True
        )
        self.fusion = nn.TransformerEncoder(encoder_layer, num_layers=2)

        # VA regression head
        self.va_head = nn.Sequential(
            nn.Linear(hidden_dim * 3, 64),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(64, 2)    # → [valence, arousal]
        )

    def forward(self, text, audio, vision):
        t = self.text_enc(text).unsqueeze(1)    # (B, 1, H)
        a = self.audio_enc(audio).unsqueeze(1)  # (B, 1, H)
        v = self.vision_enc(vision).unsqueeze(1)# (B, 1, H)

        tokens = torch.cat([t, a, v], dim=1)    # (B, 3, H)
        fused  = self.fusion(tokens)             # (B, 3, H)

        flat = fused.reshape(fused.size(0), -1) # (B, 3*H)
        out  = self.va_head(flat)               # (B, 2)

        valence = out[:, 0]
        arousal = out[:, 1]
        return valence, arousal


# ── Sanity check ──────────────────────────────────────────
model = MultimodalFusionModel(hidden_dim=128)
batch = next(iter(train_loader))

v_pred, a_pred = model(batch['text'], batch['audio'], batch['vision'])
print(f"valence_pred: {v_pred.shape}")   # → (64,)
print(f"arousal_pred: {a_pred.shape}")   # → (64,)
print(f"Params: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# valence_pred: torch.Size([64])
# arousal_pred: torch.Size([64])
# Params: 392,770

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR

# ── CCC metric ────────────────────────────────────────────
def concordance_correlation_coefficient(pred, target):
    """CCC = 2σ_xy / (σ_x² + σ_y² + (μ_x - μ_y)²)"""
    pred_mean   = pred.mean()
    target_mean = target.mean()
    pred_var    = pred.var()
    target_var  = target.var()
    covariance  = ((pred - pred_mean) * (target - target_mean)).mean()
    ccc = (2 * covariance) / (pred_var + target_var + (pred_mean - target_mean) ** 2 + 1e-8)
    return ccc

# ── Loss: MSE + CCC jointly ───────────────────────────────
def va_loss(v_pred, a_pred, v_true, a_true, alpha=0.5):
    mse_v = nn.functional.mse_loss(v_pred, v_true)
    mse_a = nn.functional.mse_loss(a_pred, a_true)
    ccc_v = 1 - concordance_correlation_coefficient(v_pred, v_true)
    ccc_a = 1 - concordance_correlation_coefficient(a_pred, a_true)
    return alpha * (mse_v + mse_a) + (1 - alpha) * (ccc_v + ccc_a)

# ── Setup ─────────────────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")

model     = MultimodalFusionModel(hidden_dim=128).to(device)
optimizer = optim.AdamW(model.parameters(), lr=3e-4, weight_decay=1e-4)
scheduler = CosineAnnealingLR(optimizer, T_max=30, eta_min=1e-6)

# ── Training loop ─────────────────────────────────────────
def run_epoch(loader, train=True):
    model.train() if train else model.eval()
    total_loss, ccc_v_sum, ccc_a_sum = 0, 0, 0

    ctx = torch.enable_grad() if train else torch.no_grad()
    with ctx:
        for batch in loader:
            text    = batch['text'].to(device)
            audio   = batch['audio'].to(device)
            vision  = batch['vision'].to(device)
            v_true  = batch['valence'].to(device)
            a_true  = batch['arousal'].to(device)

            v_pred, a_pred = model(text, audio, vision)
            loss = va_loss(v_pred, a_pred, v_true, a_true)

            if train:
                optimizer.zero_grad()
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
                optimizer.step()

            total_loss += loss.item()
            ccc_v_sum  += concordance_correlation_coefficient(v_pred.detach(), v_true).item()
            ccc_a_sum  += concordance_correlation_coefficient(a_pred.detach(), a_true).item()

    n = len(loader)
    return total_loss / n, ccc_v_sum / n, ccc_a_sum / n

# ── Train ─────────────────────────────────────────────────
EPOCHS = 30
best_val_loss = float('inf')
history = []

for epoch in range(1, EPOCHS + 1):
    tr_loss, tr_ccc_v, tr_ccc_a = run_epoch(train_loader, train=True)
    vl_loss, vl_ccc_v, vl_ccc_a = run_epoch(val_loader,   train=False)
    scheduler.step()

    history.append({
        'epoch': epoch,
        'tr_loss': tr_loss, 'vl_loss': vl_loss,
        'tr_ccc_v': tr_ccc_v, 'vl_ccc_v': vl_ccc_v,
        'tr_ccc_a': tr_ccc_a, 'vl_ccc_a': vl_ccc_a,
    })

    # Save best checkpoint
    if vl_loss < best_val_loss:
        best_val_loss = vl_loss
        torch.save(model.state_dict(), "best_model.pt")
        tag = " ← best"
    else:
        tag = ""

    if epoch % 5 == 0 or epoch == 1:
        print(
            f"Ep {epoch:02d} | "
            f"Loss {tr_loss:.4f}/{vl_loss:.4f} | "
            f"CCC-V {tr_ccc_v:.3f}/{vl_ccc_v:.3f} | "
            f"CCC-A {tr_ccc_a:.3f}/{vl_ccc_a:.3f}{tag}"
        )

print(f"\nBest val loss: {best_val_loss:.4f}")
# Out:
# Device: cpu
# Ep 01 | Loss nan/nan | CCC-V nan/nan | CCC-A nan/nan
# Ep 05 | Loss nan/nan | CCC-V nan/nan | CCC-A nan/nan
# Ep 10 | Loss nan/nan | CCC-V nan/nan | CCC-A nan/nan
# Ep 15 | Loss nan/nan | CCC-V nan/nan | CCC-A nan/nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_235/711869552.py in <cell line: 0>()
#      65
#      66 for epoch in range(1, EPOCHS + 1):
# ---> 67     tr_loss, tr_ccc_v, tr_ccc_a = run_epoch(train_loader, train=True)
#      68     vl_loss, vl_ccc_v, vl_ccc_a = run_epoch(val_loader,   train=False)
#      69     scheduler.step()
#
# /tmp/ipykernel_235/711869552.py in run_epoch(loader, train)
#      43             a_true  = batch['arousal'].to(device)
#      44
# ---> 45             v_pred, a_pred = model(text, audio, vision)
#      46             loss = va_loss(v_pred, a_pred, v_true, a_true)
#      47
#
# ...

# %%
import torch

nan_count = 0
for i in range(len(dataset)):
    s = dataset[i]
    for key in ['text', 'audio', 'vision', 'valence', 'arousal']:
        if torch.isnan(s[key]).any() or torch.isinf(s[key]).any():
            print(f"Sample {i} | key='{key}' | NaN={torch.isnan(s[key]).any()} Inf={torch.isinf(s[key]).any()}")
            nan_count += 1
            if nan_count > 10:
                break
    if nan_count > 10:
        break

print(f"\nTotal bad samples found (stopped at 10): {nan_count}")
# Out:
# Sample 15 | key='audio' | NaN=False Inf=True
# Sample 44 | key='audio' | NaN=False Inf=True
# Sample 57 | key='audio' | NaN=False Inf=True
# Sample 74 | key='audio' | NaN=False Inf=True
# Sample 77 | key='audio' | NaN=False Inf=True
# Sample 113 | key='audio' | NaN=False Inf=True
# Sample 117 | key='audio' | NaN=False Inf=True
# Sample 126 | key='audio' | NaN=False Inf=True
# Sample 148 | key='audio' | NaN=False Inf=True
# Sample 163 | key='audio' | NaN=False Inf=True
# Sample 174 | key='audio' | NaN=False Inf=True
#
# Total bad samples found (stopped at 10): 11

# %%
# Isolate whether the issue is loss or data
batch = next(iter(train_loader))
text   = batch['text']
audio  = batch['audio']
vision = batch['vision']
v_true = batch['valence']
a_true = batch['arousal']

print("Input NaNs:", torch.isnan(text).any(), torch.isnan(audio).any(), torch.isnan(vision).any())
print("Label NaNs:", torch.isnan(v_true).any(), torch.isnan(a_true).any())
print("Label range — V:", v_true.min().item(), "to", v_true.max().item())
print("Label range — A:", a_true.min().item(), "to", a_true.max().item())

# Forward pass without training
model.eval()
with torch.no_grad():
    v_pred, a_pred = model(text, audio, vision)
    print("Pred NaNs:", torch.isnan(v_pred).any(), torch.isnan(a_pred).any())
    print("Pred range — V:", v_pred.min().item(), "to", v_pred.max().item())

    mse = torch.nn.functional.mse_loss(v_pred, v_true)
    ccc = concordance_correlation_coefficient(v_pred, v_true)
    print(f"MSE: {mse.item():.4f} | CCC: {ccc.item():.4f}")
# Out:
# Input NaNs: tensor(False) tensor(False) tensor(False)
# Label NaNs: tensor(False) tensor(False)
# Label range — V: -2.6666667461395264 to 2.6666667461395264
# Label range — A: 0.0 to 2.0
# Pred NaNs: tensor(True) tensor(True)
# Pred range — V: nan to nan
# MSE: nan | CCC: nan

# %%
def pool_features(features, method='mean'):
    # Replace Inf/-Inf with NaN, then nanmean/nanmax ignores them
    features = features.copy()
    features[~np.isfinite(features)] = np.nan

    if method == 'mean':
        result = np.nanmean(features, axis=0)
    elif method == 'max':
        result = np.nanmax(features, axis=0)

    # If an entire feature column was Inf/NaN, nanmean returns NaN → replace with 0
    result = np.nan_to_num(result, nan=0.0, posinf=0.0, neginf=0.0)
    return result


class MOSEIDataset(Dataset):
    def __init__(self, mosei_dict, pool='mean'):
        self.samples = []

        for video_id, utterances in mosei_dict.items():
            for seg in utterances:
                try:
                    labels_raw  = np.array(seg['Labels']).item()
                    covarep_raw = np.array(seg['COVAREP']).item()
                    facet_raw   = np.array(seg['FACET']).item()
                    wordvec_raw = np.array(seg['WORDVEC']).item()

                    text   = pool_features(wordvec_raw['features'].astype(np.float32), pool)
                    audio  = pool_features(covarep_raw['features'].astype(np.float32), pool)
                    vision = pool_features(facet_raw['features'].astype(np.float32),   pool)

                    label_feats = labels_raw['features']
                    valence, arousal = extract_va(label_feats)

                    # Skip if labels themselves are non-finite
                    if not (np.isfinite(valence) and np.isfinite(arousal)):
                        continue

                    self.samples.append({
                        'text':    torch.tensor(text),
                        'audio':   torch.tensor(audio),
                        'vision':  torch.tensor(vision),
                        'valence': torch.tensor(valence, dtype=torch.float32),
                        'arousal': torch.tensor(arousal, dtype=torch.float32),
                        'video_id': video_id,
                    })

                except Exception as e:
                    print(f"Skipped {video_id}: {e}")

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        return self.samples[idx]


# ── Rebuild everything from scratch ───────────────────────
dataset = MOSEIDataset(mosei)
print(f"Total utterances after cleaning: {len(dataset)}")

# Verify no Infs remain
bad = sum(
    1 for i in range(len(dataset))
    for key in ['text', 'audio', 'vision']
    if not torch.isfinite(dataset[i][key]).all()
)
print(f"Remaining non-finite samples: {bad}")

# Rebuild splits and loaders
total   = len(dataset)
n_train = int(0.8 * total)
n_val   = int(0.1 * total)
n_test  = total - n_train - n_val

train_set, val_set, test_set = random_split(
    dataset, [n_train, n_val, n_test],
    generator=torch.Generator().manual_seed(42)
)

train_loader = DataLoader(train_set, batch_size=64, shuffle=True,  collate_fn=collate_fn)
val_loader   = DataLoader(val_set,   batch_size=64, shuffle=False, collate_fn=collate_fn)
test_loader  = DataLoader(test_set,  batch_size=64, shuffle=False, collate_fn=collate_fn)

# Quick forward check
model = MultimodalFusionModel(hidden_dim=128).to(device)
batch = next(iter(train_loader))
with torch.no_grad():
    v_pred, a_pred = model(batch['text'].to(device), batch['audio'].to(device), batch['vision'].to(device))
    print(f"Pred NaNs: {torch.isnan(v_pred).any()} | Pred range V: {v_pred.min():.3f} to {v_pred.max():.3f}")
# Out:
# /tmp/ipykernel_235/4143816965.py:7: RuntimeWarning: Mean of empty slice
#   result = np.nanmean(features, axis=0)
# Total utterances after cleaning: 10913
# Remaining non-finite samples: 0
# Pred NaNs: False | Pred range V: -0.378 to 0.427

# %%
model     = MultimodalFusionModel(hidden_dim=128).to(device)
optimizer = optim.AdamW(model.parameters(), lr=3e-4, weight_decay=1e-4)
scheduler = CosineAnnealingLR(optimizer, T_max=30, eta_min=1e-6)

best_val_loss = float('inf')
history = []

for epoch in range(1, 31):
    tr_loss, tr_ccc_v, tr_ccc_a = run_epoch(train_loader, train=True)
    vl_loss, vl_ccc_v, vl_ccc_a = run_epoch(val_loader,   train=False)
    scheduler.step()

    history.append({
        'epoch': epoch,
        'tr_loss': tr_loss, 'vl_loss': vl_loss,
        'tr_ccc_v': tr_ccc_v, 'vl_ccc_v': vl_ccc_v,
        'tr_ccc_a': tr_ccc_a, 'vl_ccc_a': vl_ccc_a,
    })

    if vl_loss < best_val_loss:
        best_val_loss = vl_loss
        torch.save(model.state_dict(), "best_model.pt")
        tag = " ← best"
    else:
        tag = ""

    if epoch % 5 == 0 or epoch == 1:
        print(
            f"Ep {epoch:02d} | "
            f"Loss {tr_loss:.4f}/{vl_loss:.4f} | "
            f"CCC-V {tr_ccc_v:.3f}/{vl_ccc_v:.3f} | "
            f"CCC-A {tr_ccc_a:.3f}/{vl_ccc_a:.3f}{tag}"
        )

print(f"\nBest val loss: {best_val_loss:.4f}")
# Out:
# Ep 01 | Loss 1.4223/1.2199 | CCC-V 0.275/0.491 | CCC-A 0.193/0.323 ← best
# Ep 05 | Loss 1.0415/1.0551 | CCC-V 0.560/0.604 | CCC-A 0.371/0.388 ← best
# Ep 10 | Loss 0.9228/0.9774 | CCC-V 0.626/0.632 | CCC-A 0.429/0.415 ← best
# Ep 15 | Loss 0.8374/1.0308 | CCC-V 0.660/0.629 | CCC-A 0.493/0.418
# Ep 20 | Loss 0.7832/0.9571 | CCC-V 0.690/0.643 | CCC-A 0.511/0.432
# Ep 25 | Loss 0.7321/0.9780 | CCC-V 0.712/0.641 | CCC-A 0.545/0.423
# Ep 30 | Loss 0.7217/0.9801 | CCC-V 0.719/0.640 | CCC-A 0.546/0.423
#
# Best val loss: 0.9481

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# ── Load best checkpoint ───────────────────────────────────
model.load_state_dict(torch.load("best_model.pt"))
model.eval()

# ── Test evaluation ────────────────────────────────────────
all_v_pred, all_a_pred = [], []
all_v_true, all_a_true = [], []

with torch.no_grad():
    for batch in test_loader:
        v_pred, a_pred = model(
            batch['text'].to(device),
            batch['audio'].to(device),
            batch['vision'].to(device)
        )
        all_v_pred.append(v_pred.cpu())
        all_a_pred.append(a_pred.cpu())
        all_v_true.append(batch['valence'])
        all_a_true.append(batch['arousal'])

v_pred_all = torch.cat(all_v_pred)
a_pred_all = torch.cat(all_a_pred)
v_true_all = torch.cat(all_v_true)
a_true_all = torch.cat(all_a_true)

ccc_v_test = concordance_correlation_coefficient(v_pred_all, v_true_all).item()
ccc_a_test = concordance_correlation_coefficient(a_pred_all, a_true_all).item()
mse_v_test = torch.nn.functional.mse_loss(v_pred_all, v_true_all).item()
mse_a_test = torch.nn.functional.mse_loss(a_pred_all, a_true_all).item()

print("── Test Set Results ──────────────────")
print(f"CCC-V : {ccc_v_test:.4f}")
print(f"CCC-A : {ccc_a_test:.4f}")
print(f"MSE-V : {mse_v_test:.4f}")
print(f"MSE-A : {mse_a_test:.4f}")

# ── VA Circumplex Plot ─────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
fig.patch.set_facecolor('#0a0a0f')

for ax in axes:
    ax.set_facecolor('#111118')
    ax.tick_params(colors='#64748b')
    ax.xaxis.label.set_color('#94a3b8')
    ax.yaxis.label.set_color('#94a3b8')
    for spine in ax.spines.values():
        spine.set_edgecolor('#1e1e2e')
    ax.axhline(0, color='#1e1e2e', linewidth=0.8, zorder=0)
    ax.axvline(0, color='#1e1e2e', linewidth=0.8, zorder=0)

v_t = v_true_all.numpy()
a_t = a_true_all.numpy()
v_p = v_pred_all.numpy()
a_p = a_pred_all.numpy()

# Panel 1: Ground truth
axes[0].scatter(v_t, a_t, c='#7c3aed', alpha=0.35, s=12, linewidths=0)
axes[0].set_title('Ground Truth — VA Space', color='#e2e8f0', fontsize=12, pad=12)
axes[0].set_xlabel('Valence →')
axes[0].set_ylabel('Arousal →')

# Panel 2: Predicted vs True (overlay)
axes[1].scatter(v_t, a_t, c='#1e1e2e', alpha=0.5,  s=12, linewidths=0, label='True')
axes[1].scatter(v_p, a_p, c='#0ea5e9', alpha=0.35, s=12, linewidths=0, label='Predicted')
axes[1].set_title('Predicted vs True — VA Space', color='#e2e8f0', fontsize=12, pad=12)
axes[1].set_xlabel('Valence →')
axes[1].set_ylabel('Arousal →')
legend = axes[1].legend(facecolor='#1e1e2e', edgecolor='#2e2e3e', labelcolor='#94a3b8')

# Quadrant labels on both panels
for ax in axes:
    ax.text( 0.95,  0.95, 'excited\njoyful',   transform=ax.transAxes, ha='right', va='top',    color='#10b981', fontsize=8, alpha=0.6)
    ax.text( 0.05,  0.95, 'angry\nstressed',   transform=ax.transAxes, ha='left',  va='top',    color='#ef4444', fontsize=8, alpha=0.6)
    ax.text( 0.95,  0.05, 'content\nrelaxed',  transform=ax.transAxes, ha='right', va='bottom', color='#7c3aed', fontsize=8, alpha=0.6)
    ax.text( 0.05,  0.05, 'sad\nbored',        transform=ax.transAxes, ha='left',  va='bottom', color='#64748b', fontsize=8, alpha=0.6)

fig.suptitle(
    f'Multimodal VA Prediction — CMU-MOSEI Test Set   |   CCC-V: {ccc_v_test:.3f}   CCC-A: {ccc_a_test:.3f}',
    color='#e2e8f0', fontsize=11, y=1.01
)

plt.tight_layout()
plt.savefig('va_circumplex.png', dpi=150, bbox_inches='tight', facecolor='#0a0a0f')
plt.show()
print("Saved → va_circumplex.png")

# ── Training curves ────────────────────────────────────────
fig2, axes2 = plt.subplots(1, 2, figsize=(13, 4))
fig2.patch.set_facecolor('#0a0a0f')

epochs = [h['epoch'] for h in history]

for ax in axes2:
    ax.set_facecolor('#111118')
    ax.tick_params(colors='#64748b')
    for spine in ax.spines.values():
        spine.set_edgecolor('#1e1e2e')

axes2[0].plot(epochs, [h['tr_ccc_v'] for h in history], color='#7c3aed', label='Train CCC-V')
axes2[0].plot(epochs, [h['vl_ccc_v'] for h in history], color='#7c3aed', linestyle='--', label='Val CCC-V')
axes2[0].plot(epochs, [h['tr_ccc_a'] for h in history], color='#0ea5e9', label='Train CCC-A')
axes2[0].plot(epochs, [h['vl_ccc_a'] for h in history], color='#0ea5e9', linestyle='--', label='Val CCC-A')
axes2[0].axvline(10, color='#10b981', linewidth=1, linestyle=':', alpha=0.7)
axes2[0].text(10.3, 0.1, 'best ckpt', color='#10b981', fontsize=8)
axes2[0].set_title('CCC over Epochs', color='#e2e8f0')
axes2[0].set_xlabel('Epoch', color='#94a3b8')
legend = axes2[0].legend(facecolor='#1e1e2e', edgecolor='#2e2e3e', labelcolor='#94a3b8', fontsize=8)

axes2[1].plot(epochs, [h['tr_loss'] for h in history], color='#f59e0b', label='Train Loss')
axes2[1].plot(epochs, [h['vl_loss'] for h in history], color='#f59e0b', linestyle='--', label='Val Loss')
axes2[1].axvline(10, color='#10b981', linewidth=1, linestyle=':', alpha=0.7)
axes2[1].set_title('Loss over Epochs', color='#e2e8f0')
axes2[1].set_xlabel('Epoch', color='#94a3b8')
legend2 = axes2[1].legend(facecolor='#1e1e2e', edgecolor='#2e2e3e', labelcolor='#94a3b8', fontsize=8)

plt.tight_layout()
plt.savefig('training_curves.png', dpi=150, bbox_inches='tight', facecolor='#0a0a0f')
plt.show()
print("Saved → training_curves.png")
# Out:
# ── Test Set Results ──────────────────
# CCC-V : 0.6041
# CCC-A : 0.3931
# MSE-V : 0.7661
# MSE-A : 0.3033
# Saved → va_circumplex.png
# Saved → training_curves.png

# %%
from transformers import BertTokenizer, BertModel

# ── Load BERT ──────────────────────────────────────────────
print("Loading BERT...")
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
bert      = BertModel.from_pretrained("bert-base-uncased").to(device)
bert.eval()
print("✅ BERT loaded")

# ── Extract BERT embedding for a sentence ─────────────────
def get_bert_embedding(text, max_len=40):
    """
    Returns (max_len, 768) shaped sequence
    BERT hidden size is 768 vs GloVe's 300
    """
    tokens = tokenizer(
        text,
        return_tensors="pt",
        padding="max_length",
        truncation=True,
        max_length=max_len
    ).to(device)

    with torch.no_grad():
        output = bert(**tokens)

    # (1, max_len, 768) → (max_len, 768)
    return output.last_hidden_state.squeeze(0).cpu().numpy()


#But there's one problem — BERT outputs 768 dims, your model expects 300**

#Your text encoder was trained expecting `(40, 300)` GloVe vectors. BERT outputs `(40, 768)`. You have two options:
#Option A — Project BERT output down to 300 dims  (quick fix)
#Option B — Fine-tune a new text encoder for BERT  (better, more work)
# Out:
# Loading BERT...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# ...

# %%
print("Training BERT projection layer on MELD train set...")

bert_proj.train()
model.train()  # ← GRU requires train mode for backward

# Freeze main model weights — only bert_proj will update
for param in model.parameters():
    param.requires_grad = False

proj_optimizer = Adam(bert_proj.parameters(), lr=1e-3)

PROJ_EPOCHS = 5

for epoch in range(1, PROJ_EPOCHS + 1):
    total_loss = 0
    count      = 0

    for _, row in meld['train'].iterrows():
        text    = str(row['Utterance'])
        emotion = str(row['Emotion']).lower().strip()
        if emotion not in VA_MAP:
            continue

        v_target = torch.tensor([VA_MAP[emotion][0]], dtype=torch.float32).to(device)
        a_target = torch.tensor([VA_MAP[emotion][1]], dtype=torch.float32).to(device)

        with torch.no_grad():
            emb = get_bert_embedding(text)

        emb_t     = torch.tensor(emb).unsqueeze(0).to(device)  # (1, 40, 768)
        projected = bert_proj(emb_t)                            # (1, 40, 300)

        audio_t  = torch.zeros(1, MAX_AUDIO,  74).to(device)
        vision_t = torch.zeros(1, MAX_VISION, 35).to(device)

        v_pred, a_pred = model(projected, audio_t, vision_t)

        loss = nn.functional.mse_loss(v_pred, v_target) + \
               nn.functional.mse_loss(a_pred, a_target)

        proj_optimizer.zero_grad()
        loss.backward()
        proj_optimizer.step()

        total_loss += loss.item()
        count      += 1

        if count % 1000 == 0:
            print(f"  Ep {epoch} | {count}/{len(meld['train'])} | "
                  f"avg loss={total_loss/count:.4f}")

    print(f"✅ Epoch {epoch} done | avg loss={total_loss/count:.4f}")

# Restore model to eval + unfreeze
model.eval()
for param in model.parameters():
    param.requires_grad = True
bert_proj.eval()
print("\n✅ Projection layer trained")

# ── Re-test ────────────────────────────────────────────────
test_sentences = [
    "I can't believe you did that to me",
    "this is the best day of my life",
    "I am so tired of everything",
    "yeah right, like that's ever going to happen",
    "I'm fine",
]

print("\nResults after training projection:\n")
for sentence in test_sentences:
    v_bert, a_bert = predict_va_bert(sentence)
    print(f"\"{sentence}\"")
    print(f"  BERT → V={v_bert:+.3f}  A={a_bert:.3f}  {get_region(v_bert, a_bert)}")
# Out:
# Training BERT projection layer on MELD train set...
#   Ep 1 | 1000/9989 | avg loss=2.9837
#   Ep 1 | 2000/9989 | avg loss=2.8521
#   Ep 1 | 3000/9989 | avg loss=2.7590
#   Ep 1 | 4000/9989 | avg loss=2.6864
#   Ep 1 | 5000/9989 | avg loss=2.6430
#   Ep 1 | 6000/9989 | avg loss=2.6166
#   Ep 1 | 7000/9989 | avg loss=2.5755
#   Ep 1 | 8000/9989 | avg loss=2.5879
#   Ep 1 | 9000/9989 | avg loss=2.5788
# ✅ Epoch 1 done | avg loss=2.5802
#   Ep 2 | 1000/9989 | avg loss=2.4345
#   Ep 2 | 2000/9989 | avg loss=2.4677
#   Ep 2 | 3000/9989 | avg loss=2.4363
#   Ep 2 | 4000/9989 | avg loss=2.4149
#   Ep 2 | 5000/9989 | avg loss=2.4072
#   Ep 2 | 6000/9989 | avg loss=2.3926
#   Ep 2 | 7000/9989 | avg loss=2.3676
#   Ep 2 | 8000/9989 | avg loss=2.3998
#   Ep 2 | 9000/9989 | avg loss=2.4050
# ✅ Epoch 2 done | avg loss=2.4104
#   Ep 3 | 1000/9989 | avg loss=2.3318
#   Ep 3 | 2000/9989 | avg loss=2.3795
#   Ep 3 | 3000/9989 | avg loss=2.3738
#   Ep 3 | 4000/9989 | avg loss=2.3460
# ...

# %%
retrieve_and_play_bert("ohh my god")
# Out:
# ══════════════════════════════════════════════════════════
#   Input    : "ohh my god"
#   Encoder  : BERT (context-aware)
#   Valence  : +0.2634  (positive)
#   Arousal  : 1.3035   (excited)
#   Region   : 😐 Neutral
# ══════════════════════════════════════════════════════════
#   #1 [NEUTRAL]  dist=0.846
#      Speaker : Chandler
#      Line    : "That I did. That I did."
#      Source  : S8E21  00:16:23,442 → 00:16:26,389
#
#   #2 [NEUTRAL]  dist=0.846
#      Speaker : The Interviewer
#      Line    : "So lets talk a little bit about your duties."
#      Source  : S8E21  00:16:26,820 → 00:16:29,572
#
#   #3 [NEUTRAL]  dist=0.846
#      Speaker : The Interviewer
#      Line    : "Now youll be heading a whole division, so youll have a lot of duties."
#      Source  : S8E21  00:16:41,126 → 00:16:44,337
#     <div style='background:#111;padding:16px;border-radius:8px;
#                 font-family:monospace;color:#e2e8f0;margin-bottom:8px'>
# ...

# %%
# ── Pre-compute VA predictions for all MELD clips ─────────
print("Pre-computing VA for all MELD clips using BERT...")

clip_va_cache = {}
count = 0

for key, clip in video_index.items():
    v, a = predict_va_bert(clip['utterance'])
    clip_va_cache[key] = (v, a)
    count += 1
    if count % 500 == 0:
        print(f"  {count}/{len(video_index)} done...")

print(f"✅ VA computed for {len(clip_va_cache):,} clips")

# ── Updated retrieval using per-clip predicted VA ──────────
def retrieve_and_play_bert_v2(text_input, top_k=3):
    valence, arousal = predict_va_bert(text_input)
    region = get_region(valence, arousal)

    # Match by predicted VA distance — not label VA
    scored = []
    for key, clip in video_index.items():
        if key not in clip_va_cache:
            continue
        cv, ca = clip_va_cache[key]
        dist   = np.sqrt((valence - cv)**2 + (arousal - ca)**2)
        scored.append((dist, key, clip))
    scored.sort(key=lambda x: x[0])

    print("═" * 58)
    print(f"  Input    : \"{text_input}\"")
    print(f"  Encoder  : BERT (context-aware)")
    print(f"  Valence  : {valence:+.4f}  ({'positive' if valence > 0 else 'negative'})")
    print(f"  Arousal  : {arousal:.4f}   ({'excited'  if arousal > 1 else 'calm'})")
    print(f"  Region   : {region}")
    print("═" * 58)

    for rank, (dist, (dia_id, utt_id), clip) in enumerate(scored[:top_k], 1):
        cv, ca = clip_va_cache[(dia_id, utt_id)]
        print(f"  #{rank} [{clip['emotion'].upper()}]  dist={dist:.3f}  "
              f"clip VA: V={cv:+.3f} A={ca:.3f}")
        print(f"     Speaker : {clip['speaker']}")
        print(f"     Line    : \"{clip['utterance']}\"")
        print(f"     Source  : S{clip['season']}E{clip['episode']}  "
              f"{clip['start']} → {clip['end']}\n")

    best_dist, _, best_clip = scored[0]
    dest = "/tmp/matched_clip_bert.mp4"
    shutil.copy(best_clip['path'], dest)

    display(HTML(f"""
    <div style='background:#111;padding:16px;border-radius:8px;
                font-family:monospace;color:#e2e8f0;margin-bottom:8px'>
        <div style='color:#7c3aed;font-size:13px;margin-bottom:6px'>
            BEST MATCH — {best_clip['emotion'].upper()} (BERT encoder)
        </div>
        <div style='color:#94a3b8;font-size:12px'>
            🎭 {best_clip['speaker']} &nbsp;|&nbsp;
            📺 S{best_clip['season']}E{best_clip['episode']} &nbsp;|&nbsp;
            ⏱ {best_clip['start']} → {best_clip['end']}
        </div>
        <div style='color:#e2e8f0;font-size:14px;margin-top:8px'>
            "{best_clip['utterance']}"
        </div>
        <div style='margin-top:8px;font-size:12px'>
            Your VA: V={valence:+.3f} A={arousal:.3f} → {region}
        </div>
    </div>
    """))

    display(Video(dest, embed=True, width=500))
    return valence, arousal, scored[:top_k]


# ── Test ───────────────────────────────────────────────────
retrieve_and_play_bert_v2("ohh my god")
# Out:
# Pre-computing VA for all MELD clips using BERT...
#   500/10422 done...
#   1000/10422 done...
#   1500/10422 done...
#   2000/10422 done...
#   2500/10422 done...
#   3000/10422 done...
#   3500/10422 done...
#   4000/10422 done...
#   4500/10422 done...
#   5000/10422 done...
#   5500/10422 done...
#   6000/10422 done...
#   6500/10422 done...
#   7000/10422 done...
#   7500/10422 done...
#   8000/10422 done...
#   8500/10422 done...
#   9000/10422 done...
#   9500/10422 done...
#   10000/10422 done...
# ✅ VA computed for 10,422 clips
# ══════════════════════════════════════════════════════════
#   Input    : "ohh my god"
#   Encoder  : BERT (context-aware)
#   Valence  : +0.2634  (positive)
#   Arousal  : 1.3035   (excited)
#   Region   : 😐 Neutral
# ══════════════════════════════════════════════════════════
#   #1 [SADNESS]  dist=0.005  clip VA: V=+0.266 A=1.308
#      Speaker : Monica
#      Line    : "Oh God!"
#      Source  : S3E10  00:12:48,184 → 00:12:49,225
#
# ...

# %%
retrieve_and_play_bert_v2("I am so hurt")
# Out:
# ══════════════════════════════════════════════════════════
#   Input    : "I am so hurt"
#   Encoder  : BERT (context-aware)
#   Valence  : -1.0526  (negative)
#   Arousal  : 1.4273   (excited)
#   Region   : 😠 Angry / Stressed
# ══════════════════════════════════════════════════════════
#   #1 [ANGER]  dist=0.015  clip VA: V=-1.067 A=1.431
#      Speaker : Joey
#      Line    : "Joey. Joey. Joey. Joey! Joey!!"
#      Source  : S4E20  00:00:21,813 → 00:00:27,484
#
#   #2 [NEUTRAL]  dist=0.021  clip VA: V=-1.049 A=1.407
#      Speaker : Joey
#      Line    : "Come on! you..."
#      Source  : S9E21  0:17:16,869 → 0:17:17,954
#
#   #3 [SADNESS]  dist=0.022  clip VA: V=-1.073 A=1.417
#      Speaker : Ross
#      Line    : "Thats all!"
#      Source  : S5E1  0:14:13,477 → 0:14:15,769
#     <div style='background:#111;padding:16px;border-radius:8px;
#                 font-family:monospace;color:#e2e8f0;margin-bottom:8px'>
# ...

# %%
# ── Emotion weights (inverse frequency) ───────────────────
EMOTION_WEIGHTS = {
    'neutral':  0.3,   # most common → lower weight
    'joy':      0.8,
    'surprise': 1.0,
    'anger':    1.0,
    'sadness':  1.5,   # rare → higher weight
    'disgust':  2.0,
    'fear':     2.0,
}

# ── Retrain projection with weighted loss ─────────────────
print("Retraining BERT projection with weighted loss...")

# Reset projection layer
bert_proj = nn.Sequential(
    nn.Linear(768, 512),
    nn.GELU(),
    nn.Dropout(0.2),
    nn.Linear(512, 300)
).to(device)

bert_proj.train()
model.train()

for param in model.parameters():
    param.requires_grad = False

proj_optimizer = Adam(bert_proj.parameters(), lr=5e-4)
scheduler_proj = torch.optim.lr_scheduler.CosineAnnealingLR(
    proj_optimizer, T_max=10, eta_min=1e-5
)

PROJ_EPOCHS = 10

for epoch in range(1, PROJ_EPOCHS + 1):
    total_loss = 0
    count      = 0

    # Shuffle dataframe each epoch
    train_df = meld['train'].sample(frac=1, random_state=epoch).reset_index(drop=True)

    for _, row in train_df.iterrows():
        text    = str(row['Utterance'])
        emotion = str(row['Emotion']).lower().strip()
        if emotion not in VA_MAP:
            continue

        v_target = torch.tensor([VA_MAP[emotion][0]], dtype=torch.float32).to(device)
        a_target = torch.tensor([VA_MAP[emotion][1]], dtype=torch.float32).to(device)
        weight   = EMOTION_WEIGHTS.get(emotion, 1.0)

        with torch.no_grad():
            emb = get_bert_embedding(text)

        emb_t     = torch.tensor(emb).unsqueeze(0).to(device)
        projected = bert_proj(emb_t)

        audio_t  = torch.zeros(1, MAX_AUDIO,  74).to(device)
        vision_t = torch.zeros(1, MAX_VISION, 35).to(device)

        v_pred, a_pred = model(projected, audio_t, vision_t)

        loss = weight * (
            nn.functional.mse_loss(v_pred, v_target) +
            nn.functional.mse_loss(a_pred, a_target)
        )

        proj_optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(bert_proj.parameters(), 1.0)
        proj_optimizer.step()

        total_loss += loss.item()
        count      += 1

        if count % 2000 == 0:
            print(f"  Ep {epoch} | {count}/{len(train_df)} | "
                  f"avg loss={total_loss/count:.4f}")

    scheduler_proj.step()
    print(f"✅ Epoch {epoch} | avg loss={total_loss/count:.4f}")

# Restore
model.eval()
for param in model.parameters():
    param.requires_grad = True
bert_proj.eval()
print("\n✅ Retrained with weighted loss")

# ── Test differentiation ───────────────────────────────────
test_pairs = [
    ("I am so hurt",              "sad"),
    ("ohh my god",                "surprise"),
    ("this is the best day",      "joy"),
    ("I hate you so much",        "anger"),
    ("I'm just really tired",     "sad"),
    ("we won we actually won!!",  "joy"),
]

print("\nDifferentiation test:\n")
prev_v, prev_a = None, None
for text, expected in test_pairs:
    v, a = predict_va_bert(text)
    same = "⚠️ SAME" if (prev_v and abs(v - prev_v) < 0.05
                          and abs(a - prev_a) < 0.05) else ""
    print(f"\"{text}\"")
    print(f"  expected={expected:<10} "
          f"V={v:+.3f} A={a:.3f} {get_region(v,a)} {same}")
    prev_v, prev_a = v, a
# Out:
# Retraining BERT projection with weighted loss...
#   Ep 1 | 2000/9989 | avg loss=2.7693
#   Ep 1 | 4000/9989 | avg loss=2.7138
#   Ep 1 | 6000/9989 | avg loss=2.6070
#   Ep 1 | 8000/9989 | avg loss=2.5684
# ✅ Epoch 1 | avg loss=2.5604
#   Ep 2 | 2000/9989 | avg loss=2.3023
#   Ep 2 | 4000/9989 | avg loss=2.3575
#   Ep 2 | 6000/9989 | avg loss=2.3674
#   Ep 2 | 8000/9989 | avg loss=2.3747
# ✅ Epoch 2 | avg loss=2.3627
#   Ep 3 | 2000/9989 | avg loss=2.1925
#   Ep 3 | 4000/9989 | avg loss=2.2531
#   Ep 3 | 6000/9989 | avg loss=2.2611
#   Ep 3 | 8000/9989 | avg loss=2.2835
# ✅ Epoch 3 | avg loss=2.2718
#   Ep 4 | 2000/9989 | avg loss=2.1519
#   Ep 4 | 4000/9989 | avg loss=2.2427
#   Ep 4 | 6000/9989 | avg loss=2.2241
#   Ep 4 | 8000/9989 | avg loss=2.2101
# ✅ Epoch 4 | avg loss=2.2112
#   Ep 5 | 2000/9989 | avg loss=2.1248
#   Ep 5 | 4000/9989 | avg loss=2.1550
#   Ep 5 | 6000/9989 | avg loss=2.1779
#   Ep 5 | 8000/9989 | avg loss=2.1648
# ✅ Epoch 5 | avg loss=2.1626
# ...
